# %% [markdown]
# # Homework 0

# %% [markdown]
# While we'll be using Google Colab or Jupyter servers to execute our code, keeping track of changes and such is a separate thing.  We'll use `git` for storing all the code for the course, both mine and yours.

# %% [markdown]
# First thing to do is to navigate to https://git.ucsc.edu, and get an account there.

# %% [markdown]
# Next, you should fork the PHYS 115 repo that I have set up: https://git.ucsc.edu/mhance/phys115_2023.  You can read more about forking in gitlab here: https://docs.gitlab.com/ee/user/project/repository/forking_workflow.html.
#
# You should follow the instructions for "Create a fork" and "Update your fork"

# %% [markdown]
# Now, from the new forked project: click on the "Manage/Members" link on the panel, and add me and our TA (nhamer@ucsc.edu) to your project, and give us at least "Reporter" permissions:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That's it.  When you're done, submit a link to your git project as your work for HW0 in Canvas.

# %% [markdown]
# That's it for HW 0!
